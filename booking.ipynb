# %% [markdown]
# # Booking.com web scraping

# %% [markdown]
# ### Problem statement:

# %% [markdown]
# >In this project I am scraping hotels' data from booking.com for top ten world's most-visited cities in 2018, the data frame contains 85-100 hotels per city, futhermore it is expected that the some cities in the list will be again the in the list of world's most-visited cities in 2019 for example for the fourth consecutive year, Bangkok topped the cities index with the most international overnight visitors– 22 million in all. Coming up at numbers two and three were Paris and London, respectively, with around 19 million international overnight visitors each. In short this data frame will be useful for the next coming years.<br>
# https://www.kaggle.com/shehanaaljaloud/bookingcom

# %% [markdown]
# here are the rankings of the top 10 global destination cities of 2018.<br>
# 1. Bangkok<br>
# 2. Paris<br>
# 3. London<br>
# 4. Dubai<br>
# 5. Singapore<br>
# 6. Kuala Lumpur<br>
# 7. New York<br>
# 8. Istanbul<br>
# 9. Tokyo<br>
# 10. Antalya, Turkey<br>

# %% [markdown]
# ## Data dictionary

# %% [markdown]
# |Feature|Type|Description|
# |-------|----|-----------|
# |hotel_names|object|Hotel name|
# |distance|object|The distance between hotel to center|
# |review_numbers|object|numbers of reviews that users write|
# |rate|object|rate that users|
# |city|object|the city where the hotel allocated|
# |location|float64|location of the hotel inside the city|

# %% [markdown]
# ### Importing libraries

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep 
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait

# %% [markdown]
# # 1. Bangkok

# %%
   
# Download Html page   
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-3414440&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=7bbc4de8686b0013&ss=Bangkok&ss_all=0&ssb=empty&sshis=0&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=25')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

hotel_name2 = soup2.find_all('span', attrs={'class':"sr-hotel__name"})

# Initiate empty lists to fill it with data from the web page
bangkok_names=[]
bangkok_rate=[]
bangkok_loc=[]
bangkok_review_num=[]
bangkok_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(hotel_name2)):
    bangkok_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    bangkok_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    bangkok_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    bangkok_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    bangkok_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-3414440&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=6b1c50d1815c004d&ss=Bangkok&ssb=empty&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=50')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('span', attrs={'class':"sr-hotel__name"})


# Fill empty lists with data in the second page    
for mp in range(len(n)):
    bangkok_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    bangkok_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    bangkok_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    bangkok_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    bangkok_locations.append(a.text)

# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-3414440&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=12195826d2e60027&ss=Bangkok&ss_all=0&ssb=empty&sshis=0&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=75')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
hotel_name2 = soup2.find_all('span', attrs={'class':"sr-hotel__name"})
 
# Fill empty lists with data in the third page    
for mp in range(len(n)):
    bangkok_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    bangkok_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    bangkok_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    bangkok_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    bangkok_locations.append(a.text)

# Go to fourth page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-3414440&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=12195826d2e60027&ss=Bangkok&ss_all=0&ssb=empty&sshis=0&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=75')
# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
hotel_name2 = soup2.find_all('span', attrs={'class':"sr-hotel__name"})

# Fill empty lists with data in the fourth page 
for mp in range(len(n)):
    bangkok_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    bangkok_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    bangkok_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    bangkok_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    bangkok_locations.append(a.text)
    
# Clean the text in location to be clear 
bangkok_locations1=[]
for i in bangkok_locations:
    s=str(i).replace('\n','')
    bangkok_locations1.append(str(s).replace('Show on map',''))

# %%
# Clean the text in hotel name to be clear 
bangkok_hotel_name2=[]
for i in bangkok_names:
    bangkok_hotel_name2.append(str(i).replace('\n',''))

# %%
#Create data frame for Bangkok city
bangkok_df=pd.DataFrame()
bangkok_df['hotel_names']=bangkok_names
bangkok_df['distance']=bangkok_loc
bangkok_df['review_numbers']=bangkok_review_num
bangkok_df['rate']=bangkok_rate
bangkok_df['city']='bangkok'
bangkok_df['location']=pd.Series()

# %% [markdown]
# # 2. paris

# %%
# Download Html page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-1456928&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=71d65ada52c40036&ss=Paris&ssb=empty&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Initiate empty lists to fill it with data from the web page
paris_names=[]
paris_rate=[]
paris_loc=[]
paris_review_num=[]
paris_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    paris_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    paris_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    paris_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    paris_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    paris_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-1456928&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=82635d94baa5016f&ss=Paris&ss_all=0&ssb=empty&sshis=0&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Fill empty lists with data in the second page    
for mp in range(len(n)):
    paris_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    paris_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    paris_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    paris_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    paris_locations.append(a.text)


# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-1456928&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=933f5f5f575a0199&ss=Paris&ssb=empty&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Fill empty lists with data in the third page    
for mp in range(len(n)):
    paris_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    paris_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    paris_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    paris_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    paris_locations.append(a.text)

    
# Go to fourth page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-3414440&class_interval=1&dest_id=-1456928&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=13b85f6db55502b2&ss=Paris&ss_all=0&ssb=empty&sshis=0&ssne=Bangkok&ssne_untouched=Bangkok&top_ufis=1&rows=25&offset=75')
# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Fill empty lists with data in the fourth page 
for mp in range(len(n)):
    paris_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    paris_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    paris_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    paris_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    paris_locations.append(a.text)

# Clean the text in location to be clear
paris_locations1=[]
for i in paris_locations:
    s=str(i).replace('\n','')
    paris_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Paris city
paris_df=pd.DataFrame()
paris_df['hotel_names']=paris_names
paris_df['distance']=paris_loc
paris_df['review_numbers']=paris_review_num
paris_df['rate']=paris_rate
paris_df['city']='paris'
paris_df['location']=pd.Series(paris_locations1)

# %% [markdown]
# # 3. London

# %%
# Download Html page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-3414440%3Bclass_interval%3D1%3Bdest_id%3D-1456928%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D0c765a31c0510016%3Bss%3DParis%3Bss_all%3D0%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DBangkok%3Bssne_untouched%3DBangkok%3Btop_ufis%3D1%26%3B&ss=London%2C+Greater+London%2C+United+Kingdom&is_ski_area=0&ssne=Paris&ssne_untouched=Paris&city=-1456928&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=London&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-2601889&dest_type=city&iata=LON&place_id_lat=51.507391&place_id_lon=-0.127634&search_pageview_id=0c765a31c0510016&search_selected=true')
# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n =soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Initiate empty lists to fill it with data from the web page
london_names=[]
london_rate=[]
london_loc=[]
london_review_num=[]
london_locations=[]

# Fill empty lists with data in the first page
for mp in range(len(n)):
    london_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    london_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    london_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    london_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    london_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-1456928&class_interval=1&dest_id=-2601889&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&iata=LON&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=65db5fb620bd0080&ss=London%2C%20Greater%20London%2C%20United%20Kingdom&ss_all=0&ss_raw=London&ssb=empty&sshis=0&ssne=Paris&ssne_untouched=Paris&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page   
for mp in range(len(n)):
    london_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    london_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    london_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    london_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    london_locations.append(a.text)
    
# Go to third page     
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-1456928&class_interval=1&dest_id=-2601889&dest_type=city&from_sf=1&group_adults=1&group_children=0&iata=LON&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=a3725ff7ae660025&ss=London%2C%20Greater%20London%2C%20United%20Kingdom&ss_raw=London&ssb=empty&ssne=Paris&ssne_untouched=Paris&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    london_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    london_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    london_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    london_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    london_locations.append(a.text)
    
# Go to fourth page    
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-1456928&class_interval=1&dest_id=-2601889&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&iata=LON&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=7c136006fba00057&ss=London%2C%20Greater%20London%2C%20United%20Kingdom&ss_all=0&ss_raw=London&ssb=empty&sshis=0&ssne=Paris&ssne_untouched=Paris&top_ufis=1&rows=25&offset=75')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page 
for mp in range(len(n)):
    london_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    london_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    london_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    london_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    london_locations.append(a.text)
    
# Clean the text in location to be clear     
london_locations1=[]
for i in london_locations:
    s=str(i).replace('\n','')
    london_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for London city
london_df=pd.DataFrame()
london_df['hotel_names']=london_names
london_df['distance']=london_loc
london_df['review_numbers']=london_review_num
london_df['rate']=london_rate
london_df['city']='london'
london_df['location']=pd.Series(london_locations1)

# %% [markdown]
# # 4. Dubai

# %%
# Download Html page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-1456928%3Bclass_interval%3D1%3Bdest_id%3D-2601889%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DLON%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D65db5fb620bd0080%3Bss%3DLondon%252C%2520Greater%2520London%252C%2520United%2520Kingdom%3Bss_all%3D0%3Bss_raw%3DLondon%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DParis%3Bssne_untouched%3DParis%3Btop_ufis%3D1%26%3B&ss=Dubai&is_ski_area=0&ssne=London&ssne_untouched=London&city=-2601889&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('span', attrs={'class':"sr-hotel__name"})

# Initiate empty lists to fill it with data from the web page
dubai_names=[]
dubai_rate=[]
dubai_loc=[]
dubai_review_num=[]
dubai_locations=[]

# Fill empty lists with data in the first page
for mp in range(len(n)):
    dubai_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    dubai_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    dubai_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    dubai_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    dubai_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2601889&class_interval=1&dest_id=-782831&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=28ed606e410f0347&ss=Dubai&ss_all=0&ssb=empty&sshis=0&ssne=London&ssne_untouched=London&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page
for mp in range(len(n)):
    dubai_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    dubai_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    dubai_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    dubai_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    dubai_locations.append(a.text)

# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2601889&class_interval=1&dest_id=-782831&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=6f436d533b910004&ss=Dubai&ssb=empty&ssne=London&ssne_untouched=London&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    dubai_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    dubai_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    dubai_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    dubai_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    dubai_locations.append(a.text)
    
# Go to fourth page     
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2601889&class_interval=1&dest_id=-782831&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=9f666d72c6fe0004&ss=Dubai&ssb=empty&ssne=London&ssne_untouched=London&top_ufis=1&rows=25&offset=100')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page 
for mp in range(len(n)):
    dubai_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    dubai_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    dubai_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    dubai_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
    
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    dubai_locations.append(a.text)

# Clean the text in location to be clear    
dubai_locations1=[]
for i in dubai_locations:
    s=str(i).replace('\n','')
    dubai_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Dubai city
dubai_df=pd.DataFrame()
dubai_df['hotel_names']=dubai_names
dubai_df['distance']=dubai_loc
dubai_df['review_numbers']=dubai_review_num
dubai_df['rate']=dubai_rate
dubai_df['rate']='dubai'
dubai_df['location']= pd.Series(dubai_locations1)

# %% [markdown]
# # 5. Singapore

# %%
# Download Html page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-782831%3Bclass_interval%3D1%3Bdest_id%3D-73635%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DSIN%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3Dbc146e87ad6400cc%3Bss%3DSingapore%252C%2520Singapore%3Bss_all%3D0%3Bss_raw%3DSingapore%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DDubai%3Bssne_untouched%3DDubai%3Btop_ufis%3D1%26%3B&ss=Singapore&is_ski_area=0&ssne=Singapore&ssne_untouched=Singapore&city=-73635&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('span', attrs={'class':"sr-hotel__name"})

# Initiate empty lists to fill it with data from the web page
singapore_names=[]
singapore_rate=[]
singapore_loc=[]
singapore_review_num=[]
singapore_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    singapore_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    singapore_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    singapore_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    singapore_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    singapore_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-73635&class_interval=1&dest_id=-73635&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=66e66f2767fc005b&ss=Singapore&ss_all=0&ssb=empty&sshis=0&ssne=Singapore&ssne_untouched=Singapore&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page
for mp in range(len(n)):
    singapore_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    singapore_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    singapore_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    singapore_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    singapore_locations.append(a.text)

# Go to third page    
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-73635&class_interval=1&dest_id=-73635&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=22aa6f36b68f016d&ss=Singapore&ssb=empty&ssne=Singapore&ssne_untouched=Singapore&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    singapore_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    singapore_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    singapore_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    singapore_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    singapore_locations.append(a.text)

# Go to fourth page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-73635&class_interval=1&dest_id=-73635&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=089a6f4c1cd401cd&ss=Singapore&ss_all=0&ssb=empty&sshis=0&ssne=Singapore&ssne_untouched=Singapore&top_ufis=1&rows=25&offset=75')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page
for mp in range(len(n)):
    singapore_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    singapore_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    singapore_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    singapore_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)


location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    singapore_locations.append(a.text)
    
# Clean the text in location to be clear    
singapore_locations1=[]
for i in singapore_locations:
    s=str(i).replace('\n','')
    singapore_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Singapore city
singapore_df=pd.DataFrame()
singapore_df['hotel_names']=singapore_names
singapore_df['distance']=singapore_loc
singapore_df['review_numbers']=singapore_review_num
singapore_df['rate']=singapore_rate
singapore_df['city']='singapore'
singapore_df['location']= pd.Series(singapore_locations1)

# %% [markdown]
# # 6. Kuala Lumpur

# %%
# Download Html page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-73635%3Bclass_interval%3D1%3Bdest_id%3D-2403010%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DKUL%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D56dc6f76c0f0007e%3Bss%3DKuala%2520Lumpur%252C%2520Kuala%2520Lumpur%2520Federal%2520Territory%252C%2520Malaysia%3Bss_all%3D0%3Bss_raw%3DKuala%2520Lumpur%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DSingapore%3Bssne_untouched%3DSingapore%3Btop_ufis%3D1%26%3B&ss=Kuala+Lumpur&is_ski_area=0&ssne=Kuala+Lumpur&ssne_untouched=Kuala+Lumpur&city=-2403010&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('span', attrs={'class':"sr-hotel__name"})

# Initiate empty lists to fill it with data from the web page
kuala_lumpur_names=[]
kuala_lumpur_rate=[]
kuala_lumpur_loc=[]
kuala_lumpur_review_num=[]
kuala_lumpur_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    kuala_lumpur_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    kuala_lumpur_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    kuala_lumpur_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    kuala_lumpur_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    kuala_lumpur_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2403010&class_interval=1&dest_id=-2403010&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=d84f6fb2dbb6012a&ss=Kuala%20Lumpur&ss_all=0&ssb=empty&sshis=0&ssne=Kuala%20Lumpur&ssne_untouched=Kuala%20Lumpur&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page
for mp in range(len(n)):
    kuala_lumpur_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    kuala_lumpur_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    kuala_lumpur_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    kuala_lumpur_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    kuala_lumpur_locations.append(a.text)

# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2403010&class_interval=1&dest_id=-2403010&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=eaae6fd14ecd02b1&ss=Kuala%20Lumpur&ssb=empty&ssne=Kuala%20Lumpur&ssne_untouched=Kuala%20Lumpur&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    kuala_lumpur_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    kuala_lumpur_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    kuala_lumpur_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    kuala_lumpur_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    kuala_lumpur_locations.append(a.text)

# Go to fourth page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-2403010&class_interval=1&dest_id=-2403010&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=eaff6fe00885002e&ss=Kuala%20Lumpur&ss_all=0&ssb=empty&sshis=0&ssne=Kuala%20Lumpur&ssne_untouched=Kuala%20Lumpur&top_ufis=1&rows=25&offset=75')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page
for mp in range(len(n)):
    kuala_lumpur_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    kuala_lumpur_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    kuala_lumpur_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    kuala_lumpur_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)


location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    kuala_lumpur_locations.append(a.text)
    
# Clean the text in location to be clear     
kuala_lumpur_locations1=[]
for i in kuala_lumpur_locations:
    s=str(i).replace('\n','')
    kuala_lumpur_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Kuala Lumpur city
kuala_lumpur_df=pd.DataFrame()
kuala_lumpur_df['hotel_names']=kuala_lumpur_names
kuala_lumpur_df['distance']=kuala_lumpur_loc
kuala_lumpur_df['review_numbers']=kuala_lumpur_review_num
kuala_lumpur_df['rate']=kuala_lumpur_rate
kuala_lumpur_df['city']='kuala lumpur'
kuala_lumpur_df['location']=pd.Series(kuala_lumpur_locations1)

# %% [markdown]
# # 7. New York

# %%
# Download Html page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-2403010%3Bclass_interval%3D1%3Bdest_id%3D20088325%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DNYC%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D2d887022779b0142%3Bss%3DNew%2520York%252C%2520New%2520York%2520State%252C%2520USA%3Bss_all%3D0%3Bss_raw%3DNew%2520York%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DKuala%2520Lumpur%3Bssne_untouched%3DKuala%2520Lumpur%3Btop_ufis%3D1%26%3B&ss=New+York&is_ski_area=0&ssne=New+York&ssne_untouched=New+York&city=20088325&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n =soup2.find_all('div', attrs={'class':"bui-review-score__text"})

# Initiate empty lists to fill it with data from the web page
new_york_names=[]
new_york_rate=[]
new_york_loc=[]
new_york_review_num=[]
new_york_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    new_york_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    new_york_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    new_york_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    new_york_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    new_york_locations.append(a.text)

# %%
# Go to second page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=20088325&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=7e437059c6ba002c&ss=New%20York&ss_all=0&ssb=empty&sshis=0&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page  
for mp in range(len(n)):
    new_york_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    new_york_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    new_york_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    new_york_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    new_york_locations.append(a.text)
    
# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=b56270668f1c007d&ss=New%20York&ssb=empty&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page   
for mp in range(len(n)):
    new_york_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    new_york_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    new_york_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    new_york_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    new_york_locations.append(a.text)
    
# Go to fourth page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=20088325&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=3a9670746d12002e&ss=New%20York&ss_all=0&ssb=empty&sshis=0&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=75')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page
for mp in range(len(n)):
    new_york_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    new_york_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    new_york_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    new_york_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)

location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    new_york_locations.append(a.text)

# Clean the text in location to be clear 
new_york_locations1=[]
for i in new_york_locations:
    s=str(i).replace('\n','')
    new_york_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for New York city
new_york_df=pd.DataFrame()
new_york_df['hotel_names']=new_york_names
new_york_df['distance']=new_york_loc
new_york_df['review_numbers']=new_york_review_num
new_york_df['rate']=new_york_rate
new_york_df['city']='new york'
new_york_df['location']= pd.Series(new_york_locations1)

# %% [markdown]
# # 8. Istanbul

# %%
# Download Html page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D20088325%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D7e437059c6ba002c%3Bss%3DNew%2520York%3Bss_all%3D0%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2520York%3Bssne_untouched%3DNew%2520York%3Btop_ufis%3D1%26%3B&ss=Istanbul%2C+Marmara+Region%2C+Turkey&is_ski_area=0&ssne=New+York&ssne_untouched=New+York&city=20088325&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=Istanbul&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-755070&dest_type=city&iata=IST&place_id_lat=41.008171&place_id_lon=28.974446&search_pageview_id=7e437059c6ba002c&search_selected=true')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n =soup2.find_all('div', attrs={'class':"bui-review-score__text"})

# Initiate empty lists to fill it with data from the web page
istanbul_names=[]
istanbul_rate=[]
istanbul_loc=[]
istanbul_review_num=[]
istanbul_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    istanbul_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    istanbul_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    istanbul_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    istanbul_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    istanbul_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=-755070&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&iata=IST&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=9cf070af2a0a00fc&ss=Istanbul%2C%20Marmara%20Region%2C%20Turkey&ss_all=0&ss_raw=Istanbul&ssb=empty&sshis=0&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page
for mp in range(len(n)):
    istanbul_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    istanbul_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    istanbul_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    istanbul_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    istanbul_locations.append(a.text)
    
# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=-755070&dest_type=city&from_sf=1&group_adults=1&group_children=0&iata=IST&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=d84f726d5cf10045&ss=Istanbul%2C%20Marmara%20Region%2C%20Turkey&ss_raw=Istanbul&ssb=empty&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page  
for mp in range(len(n)):
    istanbul_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    istanbul_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    istanbul_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    istanbul_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    istanbul_locations.append(a.text)

# Go to fourth page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&ac_click_type=b&ac_position=0&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=20088325&class_interval=1&dest_id=-755070&dest_type=city&from_sf=1&group_adults=1&group_children=0&iata=IST&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=fc457281730e0050&ss=Istanbul%2C%20Marmara%20Region%2C%20Turkey&ss_raw=Istanbul&ssb=empty&ssne=New%20York&ssne_untouched=New%20York&top_ufis=1&rows=25&offset=100')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page
for mp in range(len(n)):
    istanbul_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    istanbul_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    istanbul_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    istanbul_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)

location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    istanbul_locations.append(a.text)

# Clean the text in location to be clear 
istanbul_locations1=[]
for i in istanbul_locations:
    s=str(i).replace('\n','')
    istanbul_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Istanbul city
istanbul_df=pd.DataFrame()
istanbul_df['hotel_names']=istanbul_names
istanbul_df['distance']=istanbul_loc
istanbul_df['review_numbers']=istanbul_review_num
istanbul_df['rate']=istanbul_rate
istanbul_df['city']='istanbul'
istanbul_df['location']=pd.Series(istanbul_locations1)

# %% [markdown]
# # 9. Tokyo

# %%
# Download Html page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D-755070%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DIST%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D9cf070af2a0a00fc%3Bss%3DIstanbul%252C%2520Marmara%2520Region%252C%2520Turkey%3Bss_all%3D0%3Bss_raw%3DIstanbul%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2520York%3Bssne_untouched%3DNew%2520York%3Btop_ufis%3D1%26%3B&ss=Tokyo%2C+Tokyo-to%2C+Japan&is_ski_area=0&ssne=Istanbul&ssne_untouched=Istanbul&city=-755070&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=Tokyo&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-246227&dest_type=city&iata=TYO&place_id_lat=35.68596&place_id_lon=139.729518&search_pageview_id=9cf070af2a0a00fc&search_selected=true')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Initiate empty lists to fill it with data from the web page
tokyo_names=[]
tokyo_rate=[]
tokyo_loc=[]
tokyo_review_num=[]
tokyo_locations=[]

# Fill empty lists with data in the first page
for mp in range(len(n)):
    tokyo_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    tokyo_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    tokyo_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    tokyo_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    tokyo_locations.append(a.text)

# %%
# Go to second page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D-755070%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DIST%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D9cf070af2a0a00fc%3Bss%3DIstanbul%252C%2520Marmara%2520Region%252C%2520Turkey%3Bss_all%3D0%3Bss_raw%3DIstanbul%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2520York%3Bssne_untouched%3DNew%2520York%3Btop_ufis%3D1%26%3B&ss=Tokyo%2C+Tokyo-to%2C+Japan&is_ski_area=0&ssne=Istanbul&ssne_untouched=Istanbul&city=-755070&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=Tokyo&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-246227&dest_type=city&iata=TYO&place_id_lat=35.68596&place_id_lon=139.729518&search_pageview_id=9cf070af2a0a00fc&search_selected=true')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page 
for mp in range(len(n)):
    tokyo_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    tokyo_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    tokyo_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    tokyo_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    tokyo_locations.append(a.text)
    
# Go to third page     
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D-755070%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DIST%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D9cf070af2a0a00fc%3Bss%3DIstanbul%252C%2520Marmara%2520Region%252C%2520Turkey%3Bss_all%3D0%3Bss_raw%3DIstanbul%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2520York%3Bssne_untouched%3DNew%2520York%3Btop_ufis%3D1%26%3B&ss=Tokyo%2C+Tokyo-to%2C+Japan&is_ski_area=0&ssne=Istanbul&ssne_untouched=Istanbul&city=-755070&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=Tokyo&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-246227&dest_type=city&iata=TYO&place_id_lat=35.68596&place_id_lon=139.729518&search_pageview_id=9cf070af2a0a00fc&search_selected=true')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    tokyo_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    tokyo_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    tokyo_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    tokyo_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    tokyo_locations.append(a.text)
    
# Go to fourth page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D-755070%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DIST%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D9cf070af2a0a00fc%3Bss%3DIstanbul%252C%2520Marmara%2520Region%252C%2520Turkey%3Bss_all%3D0%3Bss_raw%3DIstanbul%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2520York%3Bssne_untouched%3DNew%2520York%3Btop_ufis%3D1%26%3B&ss=Tokyo%2C+Tokyo-to%2C+Japan&is_ski_area=0&ssne=Istanbul&ssne_untouched=Istanbul&city=-755070&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1&ss_raw=Tokyo&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-246227&dest_type=city&iata=TYO&place_id_lat=35.68596&place_id_lon=139.729518&search_pageview_id=9cf070af2a0a00fc&search_selected=true')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page 
for mp in range(len(n)):
    tokyo_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    tokyo_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    tokyo_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    tokyo_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
    
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    tokyo_locations.append(a.text)

# Clean the text in location to be clear 
tokyo_locations1=[]
for i in antalya_locations:
    s=str(i).replace('\n','')
    tokyo_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Tokyo city
tokyo_df=pd.DataFrame()
tokyo_df['hotel_names']=tokyo_names
tokyo_df['distance']=tokyo_loc
tokyo_df['review_numbers']=tokyo_review_num
tokyo_df['rate']=tokyo_rate
tokyo_df['city']='tokyo'
tokyo_df['location']= pd.Series( tokyo_locations1)

# %% [markdown]
# # 10. Antalya

# %%
# Download Html page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D376363%3Blabel%3Dbooking-name-L%252AXf2U1sq4%252AGEkIwcLOALQS267777916057%253Apl%253Ata%253Ap1%253Ap22%252C554%252C000%253Aac%253Aap1t1%253Aneg%253Afi%253Atikwd-65526620%253Alp1012088%253Ali%253Adec%253Adm%3Bsid%3D871c7f8bc624581703b3976c3d9057e0%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D20%3Bcheckin_year%3D2019%3Bcheckout_month%3D11%3Bcheckout_monthday%3D21%3Bcheckout_year%3D2019%3Bcity%3D-755070%3Bclass_interval%3D1%3Bdest_id%3D-246227%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D1%3Bgroup_children%3D0%3Biata%3DTYO%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3Db9c17392eb6b00f9%3Bss%3DTokyo%252C%2520Tokyo-to%252C%2520Japan%3Bss_all%3D0%3Bss_raw%3DTokyo%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DIstanbul%3Bssne_untouched%3DIstanbul%3Btop_ufis%3D1%26%3B&ss=Antalya&is_ski_area=0&ssne=Tokyo&ssne_untouched=Tokyo&city=-246227&checkin_year=2019&checkin_month=11&checkin_monthday=20&checkout_year=2019&checkout_month=11&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&from_sf=1')

# Now that we have the web page, we can parse it with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')
n = soup2.find_all('div', attrs={'class':"bui-review-score__title"})

# Initiate empty lists to fill it with data from the web page
antalya_names=[]
antalya_rate=[]
antalya_loc=[]
antalya_review_num=[]
antalya_locations=[]

# Fill empty lists with data in the first page 
for mp in range(len(n)):
    antalya_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    antalya_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    antalya_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    antalya_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)

location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    antalya_locations.append(a.text)

# %%
# Go to second page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-246227&class_interval=1&dest_id=-735347&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=89a373cb529a01d4&ss=Antalya&ss_all=0&ssb=empty&sshis=0&ssne=Tokyo&ssne_untouched=Tokyo&top_ufis=1&rows=25&offset=25')

# Parse second page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the second page 
for mp in range(len(n)):
    antalya_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    antalya_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    antalya_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    antalya_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    antalya_locations.append(a.text)
    
# Go to third page 
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-246227&class_interval=1&dest_id=-735347&dest_type=city&from_sf=1&group_adults=1&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=a7fd740f1cd702f3&ss=Antalya&ssb=empty&ssne=Tokyo&ssne_untouched=Tokyo&top_ufis=1&rows=25&offset=50')

# Parse third page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the third page
for mp in range(len(n)):
    antalya_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    antalya_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    antalya_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    antalya_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    antalya_locations.append(a.text)

# Go to fourth page
r = requests.get('https://www.booking.com/searchresults.html?aid=376363&label=booking-name-L*Xf2U1sq4*GEkIwcLOALQS267777916057%3Apl%3Ata%3Ap1%3Ap22%2C554%2C000%3Aac%3Aap1t1%3Aneg%3Afi%3Atikwd-65526620%3Alp1012088%3Ali%3Adec%3Adm&sid=871c7f8bc624581703b3976c3d9057e0&tmpl=searchresults&checkin_month=11&checkin_monthday=20&checkin_year=2019&checkout_month=11&checkout_monthday=21&checkout_year=2019&city=-246227&class_interval=1&dest_id=-735347&dest_type=city&dtdisc=0&from_sf=1&group_adults=1&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&shw_aparth=1&slp_r_match=0&src=searchresults&src_elem=sb&srpvid=9555749cf203013c&ss=Antalya&ss_all=0&ssb=empty&sshis=0&ssne=Tokyo&ssne_untouched=Tokyo&top_ufis=1&rows=25&offset=175')

# Parse fourth page with beautifulsoup
soup2 = BeautifulSoup(r.text, 'html.parser')

# Fill empty lists with data in the fourth page 
for mp in range(20):
    antalya_names.append(soup2.find_all('span', attrs={'class':"sr-hotel__name"})[mp].string)
    antalya_rate.append(soup2.find_all('div', attrs={'class':"bui-review-score__title"})[mp].string)
    antalya_loc.append(soup2.find_all('span', attrs={'data-bui-component':"Tooltip"})[mp].string)
    antalya_review_num.append(soup2.find_all('div', attrs={'class':"bui-review-score__text"})[mp].string)

    
location = soup2.find_all('div' , class_= "sr_card_address_line" )
for i in location :
    a= i.find('a')
    antalya_locations.append(a.text)

# Clean the text in location to be clear     
antalya_locations1=[]
for i in antalya_locations:
    s=str(i).replace('\n','')
    antalya_locations1.append(str(s).replace('Show on map',''))

# %%
#Create data frame for Antalya city
antalya_df=pd.DataFrame()
antalya_df['hotel_names']=antalya_names
antalya_df['distance']=antalya_loc
antalya_df['review_numbers']=antalya_review_num
antalya_df['rate']=antalya_rate
antalya_df['city']= 'antalya'
antalya_df['location']= pd.Series (antalya_locations1)

# %%
# istanbul_df
# new_york_df
# kuala_lumpur_df
# singapore_df
# dubai_df
# london_df
# paris_df
# bangkok_df
# antalya_df
# tokyo_df

# %%
df=pd.concat([istanbul_df,new_york_df,kuala_lumpur_df,singapore_df,dubai_df,london_df,paris_df,bangkok_df,antalya_df,tokyo_df ])
# Out:
# /Users/shehanaaljaloud/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.isnull().sum()
# Out:
# city              100
# distance          353
# hotel_names         0
# location          100
# rate                0
# review_numbers      0
# dtype: int64

# %%
df['location' ]= df['location'].fillna(df['city'])

# %%
df['distance'] = df['distance'].fillna(df['distance'].mode()[0])

# %%
df['city']= df.location.fillna(lambda x : str(x).split(',')[1])

# %%
df.isnull().sum()
# Out:
# city              0
# distance          0
# hotel_names       0
# location          0
# rate              0
# review_numbers    0
# dtype: int64

# %%
df.to_csv('booking.csv')
